# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("angles.csv")
df.dtypes
# Out:
# vid_id                                      int64
# frame_order                                 int64
# right_elbow_right_shoulder_right_hip      float64
# left_elbow_left_shoulder_left_hip         float64
# right_knee_mid_hip_left_knee              float64
# right_hip_right_knee_right_ankle          float64
# left_hip_left_knee_left_ankle             float64
# right_wrist_right_elbow_right_shoulder    float64
# left_wrist_left_elbow_left_shoulder       float64
# dtype: object

# %%
filtered_df = df[df['vid_id'].isin([0])]
filtered_df.drop(["vid_id"], axis=1,inplace= True ) 
filtered_df
# Out:
# C:\Users\akiri\AppData\Local\Temp\ipykernel_33284\654377070.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.drop(["vid_id"], axis=1,inplace= True )
#      frame_order  right_elbow_right_shoulder_right_hip  \
# 0              0                             16.926802
# 1              1                             14.199318
# 2              2                             18.065800
# 3              3                             23.270214
# 4              4                             22.831680
# ..           ...                                   ...
# 260          260                             13.616527
# 261          261                             16.110136
# 262          262                             14.618600
# 263          263                             25.046469
# ...

# %%
# filtered_df.drop(["frame_order"] , axis=1, inplace= True)

plt.figure(figsize=(12, 6))

for column in filtered_df.columns:
    plt.plot(filtered_df.index, filtered_df[column], label=column)

plt.legend()
plt.title("Признаки по кадрам")
plt.xlabel("Номер кадра")
plt.ylabel("Значения признаков")

plt.grid(True) 
plt.show()

# %%
x = df["frame_order"]
y  = df["right_hip_right_knee_right_ankle"]
z = np.polyfit(x,y,15)
z
# Out:
# array([-2.20511504e-29,  4.63920538e-26, -4.36925259e-23,  2.43298004e-20,
#        -8.91310603e-18,  2.26222979e-15, -4.08073697e-13,  5.28032501e-11,
#        -4.88190374e-09,  3.16539959e-07, -1.38232042e-05,  3.75101245e-04,
#        -5.33867187e-03,  2.56838573e-02,  1.25603976e-02,  1.24280350e+02])

# %%
p = np.poly1d(z)

plt.figure(figsize=(12, 6))
x1 = np.linspace(0,250, 100)
y1 = p(x1)

plt.plot(filtered_df.index, filtered_df["right_hip_right_knee_right_ankle"], label="right_hip_right_knee_right_ankle")
plt.plot(x1 , y1)

plt.legend()
plt.title("Признаки по кадрам")
plt.xlabel("Номер кадра")
plt.ylabel("Значения признаков")

plt.grid(True) 
plt.show()

# %%
df_pu = df[df['vid_id'].isin([207])]
df_pu.drop(["vid_id"], axis=1,inplace= True ) 
df_pu
# Out:
# C:\Users\akiri\AppData\Local\Temp\ipykernel_33284\2025353608.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pu.drop(["vid_id"], axis=1,inplace= True )
#        frame_order  right_elbow_right_shoulder_right_hip  \
# 37909            0                             163.29631
# 37910            1                             163.02322
# 37911            2                             154.10771
# 37912            3                             141.23483
# 37913            4                             135.98425
# ...            ...                                   ...
# 38064          155                             134.58835
# 38065          156                             136.49623
# 38066          157                             143.73279
# ...

# %%
plt.figure(figsize= (10,5))
# df_pu.drop(["frame_order"] , axis =1 , inplace=True)
for columns in df_pu.columns:
    plt.plot(df_pu.index , df_pu[columns], label = columns)
plt.legend()
plt.title("Признаки по кадрам")
plt.xlabel("Номер кадра")
plt.ylabel("Значения признаков")
plt.grid(True)
plt.show()
